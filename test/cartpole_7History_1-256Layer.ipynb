# %%
# %matplotlib inline
from collections import deque, namedtuple
import itertools
import numpy as np
from matplotlib import pyplot as plt
import gym
import random

from keras.models import Sequential, load_model
from keras.layers import Dense, Activation
from keras.optimizers import RMSprop
from keras import backend as K

np.random.seed(1337)  # for reproducibility
# Out:
# Using TensorFlow backend.

# %%
#set hyperparameters
AGENT_HISTORY_LENGTH = 7
TWO_LAYER = False
THREE_LAYER = False
HIDDEN_LAYER_1_NODE = 256
HIDDEN_LAYER_2_NODE = 256
HIDDEN_LAYER_3_NODE = 256

#set hyperparameters
MINI_BATCH_SIZE = 64
REPLAY_MEMORY_SIZE = 10000
TARGET_NETWORK_UPDATE_FREQUENCY = 5000
DISCOUNT_FACTOR = 0.99
UPDATE_FREQUENCY = 4
LEARNING_RATE = 0.00025
INITIAL_EXPLORATION = 1
FINAL_EXPLORATION = 0.1
FINAL_EXPLORATION_FRAME = 10000
REPLAY_START_SIZE = REPLAY_MEMORY_SIZE
NUM_EPISODES = 5000

LIMIT_MAX_SCORE = 1000
AVG_SCORE_TO_END = 500
AVG_EP = 100

# %%
#setup game env
GAME = "CartPole-v0"
env = gym.envs.make(GAME)
env.seed(1337)  # for reproducibility
NUMBER_OF_ACTIONS = env.action_space.n
observation = env.reset()
# Out:
# [2017-03-01 19:46:11,485] Making new env: CartPole-v0

# %%
# define the loss function

def mean_squared_error(y_true, y_pred):
    return K.mean(K.square(y_pred - y_true), axis=-1)

def cliped_mean_squared_error(y_true, y_pred):
    return K.clip(K.mean(K.square(y_pred - y_true), axis=-1), -1, 1)

# %%
# build the model
# input shape is AGENT_HISTORY_LENGT * observation.shape[0]
# output shape is NUMBER_OF_ACTIONS
# using 1 relu hidden layer 
# mean_squared_error as a loss function
def build_model():
    
    model = Sequential()
    input_shape = (AGENT_HISTORY_LENGTH*observation.shape[0])
    model.add(Dense(HIDDEN_LAYER_1_NODE,input_dim=input_shape))
    model.add(Activation('relu'))
    if TWO_LAYER or THREE_LAYER:
        model.add(Dense(HIDDEN_LAYER_2_NODE))
        model.add(Activation('relu'))
    if THREE_LAYER :    
        model.add(Dense(HIDDEN_LAYER_3_NODE))
        model.add(Activation('relu'))
    model.add(Dense(NUMBER_OF_ACTIONS))
    model.add(Activation('linear'))
    model.compile(loss=mean_squared_error, optimizer=RMSprop(lr=LEARNING_RATE))
    return model

# %%
# Initialize everything
episode_rewards = np.zeros(NUM_EPISODES)
episode_lengths = np.zeros(NUM_EPISODES)
loss = np.zeros(NUM_EPISODES)
total_frame = 0
max_reward = 0
max_ep = 0


# replay memory
replay_memory =  deque(maxlen = REPLAY_MEMORY_SIZE);
Transition = namedtuple("Transition", ["state", "action", "reward", "next_state", "done"])

# state history
state_history = deque(maxlen = AGENT_HISTORY_LENGTH);

# The epsilon decay schedule
epsilons = np.linspace(INITIAL_EXPLORATION, FINAL_EXPLORATION, FINAL_EXPLORATION_FRAME)

# build model
train_model = build_model()
target_model = build_model()
target_model.set_weights(train_model.get_weights())

# %%
#init replay memmory

replay_size = 0

for i in itertools.count():

    state = env.reset()
    # init state
    state = np.array(state)
    for _ in xrange(AGENT_HISTORY_LENGTH):
        state_history.append(state)
    state = np.array(state_history)
    state = state.flatten()

    for t in itertools.count():
        #  random action
        action = np.random.randint(NUMBER_OF_ACTIONS)       
        next_state, reward, done, info = env.step(action)
        
        # set the negative reward when the game end  
        if done == True :
            reward = -5

        # clip reward [-5,1]
        reward = max(-5, min(1, reward))
        
        # append next state
        next_state = np.array(next_state)
        state_history.append(next_state)
        next_state = np.array(state_history)
        next_state = next_state.flatten()
        
        # Save transition to replay memory
        replay_memory.append(Transition(state, action, reward, next_state, done))   
        
        # check if terminated
        replay_size +=1
        if done:
            break
        else:
            state = next_state
         
    # stop when replay memory full    
    if replay_size > REPLAY_START_SIZE :
        print "Done init replay memory (ep:%i)" %(i)
        break
# Out:
# Done init replay memory (ep:464)

# %%
for i_episode in xrange(NUM_EPISODES):

    state = env.reset()
    # init state
    state = np.array(state)
    for _ in xrange(AGENT_HISTORY_LENGTH):
        state_history.append(state)
    state = np.array(state_history)
    state = state.flatten()

    count_ran = 0
    count_q = 0

    for t in itertools.count():
        # step random action
        if np.random.random() < epsilons[min(total_frame,FINAL_EXPLORATION_FRAME-1)]:
                count_ran += 1
                action = np.random.randint(NUMBER_OF_ACTIONS)       
        else:
                count_q += 1
                q_values = train_model.predict(np.array([state]))[0]
                action = np.argmax(q_values)

        next_state, reward, done, info = env.step(action)
        
        # set the negative reward when the game end  
        if done == True :
            reward = -5

        # clip reward [-5,1]
        reward = max(-5, min(1, reward))
        
        # append next state
        next_state = np.array(next_state)
        state_history.append(next_state)
        next_state = np.array(state_history)
        next_state = next_state.flatten()
        
        # Save transition to replay memory
        replay_memory.append(Transition(state, action, reward, next_state, done))   
        
        # Update statistics
        total_frame += 1
        episode_rewards[i_episode] += reward
        episode_lengths[i_episode] = t
        
        # train network    
        if total_frame % UPDATE_FREQUENCY == 0 and total_frame != 0 :
            # Sample a minibatch from the replay memory
            samples = random.sample(replay_memory, MINI_BATCH_SIZE)
            states_batch, action_batch, reward_batch, next_states_batch, done_batch = map(np.array, zip(*samples))

            # Calculate q values and targets
            q_values = train_model.predict(states_batch)
            q_values_next = target_model.predict(next_states_batch)
            new_q_values_batch = reward_batch + np.invert(done_batch).astype(np.float32) * DISCOUNT_FACTOR * np.amax(q_values_next, axis=1)
            for b in xrange(MINI_BATCH_SIZE) :
                q_values[b][action_batch[b]] = new_q_values_batch[b]
            targets_batch = q_values

            # Perform gradient descent update
            states_batch = np.array(states_batch)
            loss[i_episode] = train_model.train_on_batch(states_batch, targets_batch)
        

        # check if terminated
        if done or t > LIMIT_MAX_SCORE :
            break
        else:
            state = next_state
            

                
        # update target network    
        if total_frame != 0 and total_frame % TARGET_NETWORK_UPDATE_FREQUENCY == 0:
            target_model.set_weights(train_model.get_weights())      
    
    ####### EPISODE END
    
        
    if max_reward < episode_rewards[i_episode] :
        max_reward = episode_rewards[i_episode]
        max_ep = i_episode
    # print statistics    
    print 'Ep:%i\treward:%i\trandom_act:%i\tpredict_act:%i' % (i_episode,episode_rewards[i_episode],count_ran, count_q)

    if episode_rewards[i_episode]>AVG_SCORE_TO_END and np.mean(episode_rewards[i_episode-AVG_EP:i_episode+1])>AVG_SCORE_TO_END:
        print("Stopped - 500 avg scores reached!")
        break
# Out:
# Ep:0	reward:10	random_act:16	predict_act:0
# Ep:1	reward:3	random_act:9	predict_act:0
# Ep:2	reward:13	random_act:19	predict_act:0
# Ep:3	reward:3	random_act:9	predict_act:0
# Ep:4	reward:36	random_act:42	predict_act:0
# Ep:5	reward:6	random_act:12	predict_act:0
# Ep:6	reward:6	random_act:12	predict_act:0
# Ep:7	reward:19	random_act:25	predict_act:0
# Ep:8	reward:30	random_act:35	predict_act:1
# Ep:9	reward:15	random_act:21	predict_act:0
# Ep:10	reward:6	random_act:12	predict_act:0
# Ep:11	reward:25	random_act:31	predict_act:0
# Ep:12	reward:16	random_act:21	predict_act:1
# Ep:13	reward:10	random_act:15	predict_act:1
# Ep:14	reward:6	random_act:12	predict_act:0
# Ep:15	reward:13	random_act:19	predict_act:0
# Ep:16	reward:31	random_act:36	predict_act:1
# Ep:17	reward:6	random_act:11	predict_act:1
# Ep:18	reward:4	random_act:9	predict_act:1
# Ep:19	reward:6	random_act:11	predict_act:1
# Ep:20	reward:11	random_act:17	predict_act:0
# Ep:21	reward:48	random_act:54	predict_act:0
# Ep:22	reward:21	random_act:24	predict_act:3
# Ep:23	reward:15	random_act:19	predict_act:2
# Ep:24	reward:5	random_act:10	predict_act:1
# Ep:25	reward:11	random_act:17	predict_act:0
# Ep:26	reward:5	random_act:8	predict_act:3
# Ep:27	reward:15	random_act:21	predict_act:0
# Ep:28	reward:21	random_act:27	predict_act:0
# Ep:29	reward:8	random_act:14	predict_act:0
# Ep:30	reward:22	random_act:25	predict_act:3
# Ep:31	reward:30	random_act:35	predict_act:1
# Ep:32	reward:20	random_act:26	predict_act:0
# Ep:33	reward:15	random_act:21	predict_act:0
# Ep:34	reward:7	random_act:10	predict_act:3
# Ep:35	reward:3	random_act:8	predict_act:1
# Ep:36	reward:11	random_act:16	predict_act:1
# Ep:37	reward:5	random_act:11	predict_act:0
# Ep:38	reward:13	random_act:19	predict_act:0
# Ep:39	reward:6	random_act:12	predict_act:0
# Ep:40	reward:8	random_act:13	predict_act:1
# Ep:41	reward:24	random_act:27	predict_act:3
# Ep:42	reward:29	random_act:31	predict_act:4
# Ep:43	reward:20	random_act:26	predict_act:0
# Ep:44	reward:8	random_act:13	predict_act:1
# Ep:45	reward:11	random_act:17	predict_act:0
# Ep:46	reward:9	random_act:14	predict_act:1
# Ep:47	reward:6	random_act:12	predict_act:0
# Ep:48	reward:38	random_act:34	predict_act:10
# Ep:49	reward:15	random_act:19	predict_act:2
# Ep:50	reward:12	random_act:16	predict_act:2
# Ep:51	reward:6	random_act:11	predict_act:1
# Ep:52	reward:21	random_act:23	predict_act:4
# Ep:53	reward:12	random_act:17	predict_act:1
# Ep:54	reward:7	random_act:12	predict_act:1
# Ep:55	reward:9	random_act:14	predict_act:1
# Ep:56	reward:10	random_act:16	predict_act:0
# Ep:57	reward:13	random_act:19	predict_act:0
# Ep:58	reward:13	random_act:17	predict_act:2
# Ep:59	reward:33	random_act:32	predict_act:7
# Ep:60	reward:36	random_act:37	predict_act:5
# Ep:61	reward:9	random_act:12	predict_act:3
# Ep:62	reward:11	random_act:15	predict_act:2
# Ep:63	reward:28	random_act:29	predict_act:5
# Ep:64	reward:24	random_act:27	predict_act:3
# Ep:65	reward:19	random_act:21	predict_act:4
# Ep:66	reward:11	random_act:14	predict_act:3
# Ep:67	reward:37	random_act:38	predict_act:5
# Ep:68	reward:20	random_act:24	predict_act:2
# Ep:69	reward:10	random_act:14	predict_act:2
# Ep:70	reward:59	random_act:62	predict_act:3
# Ep:71	reward:7	random_act:12	predict_act:1
# Ep:72	reward:6	random_act:10	predict_act:2
# Ep:73	reward:32	random_act:35	predict_act:3
# Ep:74	reward:51	random_act:47	predict_act:10
# Ep:75	reward:4	random_act:8	predict_act:2
# Ep:76	reward:13	random_act:18	predict_act:1
# Ep:77	reward:10	random_act:14	predict_act:2
# Ep:78	reward:13	random_act:17	predict_act:2
# Ep:79	reward:30	random_act:28	predict_act:8
# Ep:80	reward:13	random_act:18	predict_act:1
# Ep:81	reward:22	random_act:24	predict_act:4
# Ep:82	reward:10	random_act:13	predict_act:3
# Ep:83	reward:7	random_act:12	predict_act:1
# Ep:84	reward:26	random_act:27	predict_act:5
# Ep:85	reward:10	random_act:11	predict_act:5
# Ep:86	reward:22	random_act:26	predict_act:2
# Ep:87	reward:8	random_act:12	predict_act:2
# Ep:88	reward:23	random_act:25	predict_act:4
# Ep:89	reward:5	random_act:9	predict_act:2
# Ep:90	reward:16	random_act:17	predict_act:5
# Ep:91	reward:12	random_act:13	predict_act:5
# Ep:92	reward:24	random_act:25	predict_act:5
# Ep:93	reward:33	random_act:30	predict_act:9
# Ep:94	reward:9	random_act:9	predict_act:6
# Ep:95	reward:5	random_act:6	predict_act:5
# Ep:96	reward:21	random_act:21	predict_act:6
# Ep:97	reward:7	random_act:9	predict_act:4
# Ep:98	reward:21	random_act:22	predict_act:5
# Ep:99	reward:15	random_act:18	predict_act:3
# Ep:100	reward:7	random_act:9	predict_act:4
# Ep:101	reward:9	random_act:11	predict_act:4
# Ep:102	reward:27	random_act:29	predict_act:4
# Ep:103	reward:26	random_act:26	predict_act:6
# Ep:104	reward:9	random_act:12	predict_act:3
# Ep:105	reward:21	random_act:24	predict_act:3
# Ep:106	reward:10	random_act:15	predict_act:1
# Ep:107	reward:4	random_act:7	predict_act:3
# Ep:108	reward:5	random_act:10	predict_act:1
# Ep:109	reward:11	random_act:14	predict_act:3
# Ep:110	reward:7	random_act:12	predict_act:1
# Ep:111	reward:38	random_act:32	predict_act:12
# Ep:112	reward:18	random_act:17	predict_act:7
# Ep:113	reward:11	random_act:15	predict_act:2
# Ep:114	reward:10	random_act:14	predict_act:2
# Ep:115	reward:19	random_act:14	predict_act:11
# Ep:116	reward:12	random_act:11	predict_act:7
# Ep:117	reward:9	random_act:10	predict_act:5
# Ep:118	reward:21	random_act:23	predict_act:4
# Ep:119	reward:8	random_act:11	predict_act:3
# Ep:120	reward:8	random_act:10	predict_act:4
# Ep:121	reward:12	random_act:14	predict_act:4
# Ep:122	reward:18	random_act:21	predict_act:3
# Ep:123	reward:24	random_act:22	predict_act:8
# Ep:124	reward:4	random_act:7	predict_act:3
# Ep:125	reward:16	random_act:18	predict_act:4
# Ep:126	reward:22	random_act:20	predict_act:8
# Ep:127	reward:4	random_act:4	predict_act:6
# Ep:128	reward:11	random_act:10	predict_act:7
# Ep:129	reward:11	random_act:13	predict_act:4
# Ep:130	reward:6	random_act:10	predict_act:2
# Ep:131	reward:41	random_act:38	predict_act:9
# Ep:132	reward:14	random_act:17	predict_act:3
# Ep:133	reward:17	random_act:16	predict_act:7
# Ep:134	reward:7	random_act:10	predict_act:3
# Ep:135	reward:41	random_act:26	predict_act:21
# Ep:136	reward:19	random_act:16	predict_act:9
# Ep:137	reward:29	random_act:26	predict_act:9
# Ep:138	reward:31	random_act:29	predict_act:8
# Ep:139	reward:5	random_act:9	predict_act:2
# Ep:140	reward:10	random_act:11	predict_act:5
# Ep:141	reward:15	random_act:14	predict_act:7
# Ep:142	reward:25	random_act:23	predict_act:8
# Ep:143	reward:31	random_act:29	predict_act:8
# Ep:144	reward:8	random_act:11	predict_act:3
# Ep:145	reward:8	random_act:12	predict_act:2
# Ep:146	reward:22	random_act:21	predict_act:7
# Ep:147	reward:22	random_act:20	predict_act:8
# Ep:148	reward:22	random_act:19	predict_act:9
# Ep:149	reward:9	random_act:10	predict_act:5
# Ep:150	reward:15	random_act:18	predict_act:3
# Ep:151	reward:37	random_act:32	predict_act:11
# Ep:152	reward:8	random_act:10	predict_act:4
# Ep:153	reward:11	random_act:10	predict_act:7
# Ep:154	reward:33	random_act:32	predict_act:7
# Ep:155	reward:5	random_act:8	predict_act:3
# Ep:156	reward:22	random_act:23	predict_act:5
# Ep:157	reward:7	random_act:7	predict_act:6
# Ep:158	reward:7	random_act:11	predict_act:2
# Ep:159	reward:39	random_act:30	predict_act:15
# Ep:160	reward:18	random_act:10	predict_act:14
# Ep:161	reward:8	random_act:8	predict_act:6
# Ep:162	reward:9	random_act:10	predict_act:5
# Ep:163	reward:3	random_act:5	predict_act:4
# Ep:164	reward:3	random_act:4	predict_act:5
# Ep:165	reward:7	random_act:8	predict_act:5
# Ep:166	reward:12	random_act:9	predict_act:9
# Ep:167	reward:4	random_act:6	predict_act:4
# Ep:168	reward:16	random_act:15	predict_act:7
# Ep:169	reward:16	random_act:15	predict_act:7
# Ep:170	reward:9	random_act:14	predict_act:1
# Ep:171	reward:13	random_act:14	predict_act:5
# Ep:172	reward:21	random_act:17	predict_act:10
# Ep:173	reward:10	random_act:9	predict_act:7
# Ep:174	reward:3	random_act:7	predict_act:2
# Ep:175	reward:24	random_act:17	predict_act:13
# Ep:176	reward:14	random_act:16	predict_act:4
# Ep:177	reward:8	random_act:9	predict_act:5
# Ep:178	reward:13	random_act:11	predict_act:8
# Ep:179	reward:9	random_act:9	predict_act:6
# Ep:180	reward:7	random_act:9	predict_act:4
# Ep:181	reward:6	random_act:10	predict_act:2
# Ep:182	reward:8	random_act:11	predict_act:3
# Ep:183	reward:19	random_act:16	predict_act:9
# Ep:184	reward:57	random_act:36	predict_act:27
# Ep:185	reward:4	random_act:6	predict_act:4
# Ep:186	reward:6	random_act:8	predict_act:4
# Ep:187	reward:9	random_act:6	predict_act:9
# Ep:188	reward:10	random_act:10	predict_act:6
# Ep:189	reward:7	random_act:5	predict_act:8
# Ep:190	reward:6	random_act:7	predict_act:5
# Ep:191	reward:14	random_act:12	predict_act:8
# Ep:192	reward:5	random_act:6	predict_act:5
# Ep:193	reward:15	random_act:10	predict_act:11
# Ep:194	reward:12	random_act:13	predict_act:5
# Ep:195	reward:12	random_act:13	predict_act:5
# Ep:196	reward:9	random_act:7	predict_act:8
# Ep:197	reward:5	random_act:6	predict_act:5
# Ep:198	reward:8	random_act:7	predict_act:7
# Ep:199	reward:11	random_act:8	predict_act:9
# Ep:200	reward:10	random_act:9	predict_act:7
# Ep:201	reward:28	random_act:23	predict_act:11
# Ep:202	reward:11	random_act:12	predict_act:5
# Ep:203	reward:13	random_act:11	predict_act:8
# Ep:204	reward:6	random_act:7	predict_act:5
# Ep:205	reward:17	random_act:17	predict_act:6
# Ep:206	reward:10	random_act:11	predict_act:5
# Ep:207	reward:24	random_act:22	predict_act:8
# Ep:208	reward:11	random_act:7	predict_act:10
# Ep:209	reward:6	random_act:5	predict_act:7
# Ep:210	reward:9	random_act:9	predict_act:6
# Ep:211	reward:3	random_act:6	predict_act:3
# Ep:212	reward:12	random_act:13	predict_act:5
# Ep:213	reward:3	random_act:4	predict_act:5
# Ep:214	reward:3	random_act:3	predict_act:6
# Ep:215	reward:11	random_act:9	predict_act:8
# Ep:216	reward:4	random_act:3	predict_act:7
# Ep:217	reward:12	random_act:11	predict_act:7
# Ep:218	reward:22	random_act:19	predict_act:9
# Ep:219	reward:12	random_act:14	predict_act:4
# Ep:220	reward:3	random_act:5	predict_act:4
# Ep:221	reward:11	random_act:10	predict_act:7
# Ep:222	reward:16	random_act:12	predict_act:10
# Ep:223	reward:12	random_act:11	predict_act:7
# Ep:224	reward:17	random_act:11	predict_act:12
# Ep:225	reward:10	random_act:8	predict_act:8
# Ep:226	reward:7	random_act:6	predict_act:7
# Ep:227	reward:6	random_act:8	predict_act:4
# Ep:228	reward:12	random_act:13	predict_act:5
# Ep:229	reward:6	random_act:5	predict_act:7
# Ep:230	reward:4	random_act:4	predict_act:6
# Ep:231	reward:8	random_act:10	predict_act:4
# Ep:232	reward:8	random_act:8	predict_act:6
# Ep:233	reward:3	random_act:5	predict_act:4
# Ep:234	reward:11	random_act:11	predict_act:6
# Ep:235	reward:13	random_act:14	predict_act:5
# Ep:236	reward:11	random_act:8	predict_act:9
# Ep:237	reward:9	random_act:8	predict_act:7
# Ep:238	reward:15	random_act:10	predict_act:11
# Ep:239	reward:8	random_act:8	predict_act:6
# Ep:240	reward:4	random_act:5	predict_act:5
# Ep:241	reward:6	random_act:7	predict_act:5
# Ep:242	reward:10	random_act:12	predict_act:4
# Ep:243	reward:9	random_act:11	predict_act:4
# Ep:244	reward:7	random_act:8	predict_act:5
# Ep:245	reward:6	random_act:6	predict_act:6
# Ep:246	reward:5	random_act:6	predict_act:5
# Ep:247	reward:4	random_act:6	predict_act:4
# Ep:248	reward:24	random_act:15	predict_act:15
# Ep:249	reward:16	random_act:13	predict_act:9
# Ep:250	reward:3	random_act:2	predict_act:7
# Ep:251	reward:13	random_act:13	predict_act:6
# Ep:252	reward:8	random_act:10	predict_act:4
# Ep:253	reward:18	random_act:15	predict_act:9
# Ep:254	reward:27	random_act:15	predict_act:18
# Ep:255	reward:31	random_act:21	predict_act:16
# Ep:256	reward:8	random_act:7	predict_act:7
# Ep:257	reward:36	random_act:14	predict_act:28
# Ep:258	reward:33	random_act:21	predict_act:18
# Ep:259	reward:42	random_act:21	predict_act:27
# Ep:260	reward:9	random_act:12	predict_act:3
# Ep:261	reward:8	random_act:7	predict_act:7
# Ep:262	reward:6	random_act:4	predict_act:8
# Ep:263	reward:66	random_act:37	predict_act:35
# Ep:264	reward:6	random_act:6	predict_act:6
# Ep:265	reward:18	random_act:8	predict_act:16
# Ep:266	reward:23	random_act:13	predict_act:16
# Ep:267	reward:9	random_act:7	predict_act:8
# Ep:268	reward:5	random_act:3	predict_act:8
# Ep:269	reward:3	random_act:2	predict_act:7
# Ep:270	reward:27	random_act:23	predict_act:10
# Ep:271	reward:7	random_act:7	predict_act:6
# Ep:272	reward:4	random_act:4	predict_act:6
# Ep:273	reward:22	random_act:17	predict_act:11
# Ep:274	reward:31	random_act:20	predict_act:17
# Ep:275	reward:8	random_act:10	predict_act:4
# Ep:276	reward:16	random_act:10	predict_act:12
# Ep:277	reward:3	random_act:7	predict_act:2
# Ep:278	reward:8	random_act:9	predict_act:5
# Ep:279	reward:39	random_act:21	predict_act:24
# Ep:280	reward:62	random_act:35	predict_act:33
# Ep:281	reward:5	random_act:2	predict_act:9
# Ep:282	reward:4	random_act:5	predict_act:5
# Ep:283	reward:7	random_act:7	predict_act:6
# Ep:284	reward:6	random_act:2	predict_act:10
# Ep:285	reward:4	random_act:5	predict_act:5
# Ep:286	reward:10	random_act:6	predict_act:10
# Ep:287	reward:3	random_act:4	predict_act:5
# Ep:288	reward:4	random_act:4	predict_act:6
# Ep:289	reward:9	random_act:8	predict_act:7
# Ep:290	reward:5	random_act:4	predict_act:7
# Ep:291	reward:5	random_act:5	predict_act:6
# Ep:292	reward:14	random_act:11	predict_act:9
# Ep:293	reward:7	random_act:6	predict_act:7
# Ep:294	reward:8	random_act:8	predict_act:6
# Ep:295	reward:39	random_act:21	predict_act:24
# Ep:296	reward:2	random_act:4	predict_act:4
# Ep:297	reward:20	random_act:17	predict_act:9
# Ep:298	reward:12	random_act:7	predict_act:11
# Ep:299	reward:47	random_act:24	predict_act:29
# Ep:300	reward:10	random_act:7	predict_act:9
# Ep:301	reward:7	random_act:5	predict_act:8
# Ep:302	reward:22	random_act:14	predict_act:14
# Ep:303	reward:53	random_act:26	predict_act:33
# Ep:304	reward:47	random_act:23	predict_act:30
# Ep:305	reward:19	random_act:10	predict_act:15
# Ep:306	reward:4	random_act:5	predict_act:5
# Ep:307	reward:8	random_act:7	predict_act:7
# Ep:308	reward:11	random_act:10	predict_act:7
# Ep:309	reward:5	random_act:4	predict_act:7
# Ep:310	reward:25	random_act:18	predict_act:13
# Ep:311	reward:71	random_act:29	predict_act:48
# Ep:312	reward:71	random_act:32	predict_act:45
# Ep:313	reward:5	random_act:2	predict_act:9
# Ep:314	reward:22	random_act:13	predict_act:15
# Ep:315	reward:87	random_act:32	predict_act:61
# Ep:316	reward:18	random_act:8	predict_act:16
# Ep:317	reward:26	random_act:19	predict_act:13
# Ep:318	reward:4	random_act:2	predict_act:8
# Ep:319	reward:35	random_act:14	predict_act:27
# Ep:320	reward:14	random_act:11	predict_act:9
# Ep:321	reward:2	random_act:2	predict_act:6
# Ep:322	reward:33	random_act:13	predict_act:26
# Ep:323	reward:24	random_act:10	predict_act:20
# Ep:324	reward:63	random_act:18	predict_act:51
# Ep:325	reward:9	random_act:3	predict_act:12
# Ep:326	reward:86	random_act:22	predict_act:70
# Ep:327	reward:67	random_act:25	predict_act:48
# Ep:328	reward:25	random_act:9	predict_act:22
# Ep:329	reward:110	random_act:33	predict_act:83
# Ep:330	reward:4	random_act:5	predict_act:5
# Ep:331	reward:56	random_act:18	predict_act:44
# Ep:332	reward:99	random_act:40	predict_act:65
# Ep:333	reward:57	random_act:19	predict_act:44
# Ep:334	reward:5	random_act:3	predict_act:8
# Ep:335	reward:47	random_act:20	predict_act:33
# Ep:336	reward:2	random_act:2	predict_act:6
# Ep:337	reward:5	random_act:3	predict_act:8
# Ep:338	reward:18	random_act:8	predict_act:16
# Ep:339	reward:7	random_act:7	predict_act:6
# Ep:340	reward:24	random_act:15	predict_act:15
# Ep:341	reward:3	random_act:4	predict_act:5
# Ep:342	reward:4	random_act:0	predict_act:10
# Ep:343	reward:4	random_act:3	predict_act:7
# Ep:344	reward:5	random_act:3	predict_act:8
# Ep:345	reward:57	random_act:15	predict_act:48
# Ep:346	reward:10	random_act:9	predict_act:7
# Ep:347	reward:21	random_act:5	predict_act:22
# Ep:348	reward:9	random_act:4	predict_act:11
# Ep:349	reward:120	random_act:42	predict_act:84
# Ep:350	reward:5	random_act:2	predict_act:9
# Ep:351	reward:6	random_act:4	predict_act:8
# Ep:352	reward:8	random_act:2	predict_act:12
# Ep:353	reward:127	random_act:36	predict_act:97
# Ep:354	reward:11	random_act:6	predict_act:11
# Ep:355	reward:4	random_act:2	predict_act:8
# Ep:356	reward:18	random_act:9	predict_act:15
# Ep:357	reward:11	random_act:6	predict_act:11
# Ep:358	reward:18	random_act:5	predict_act:19
# Ep:359	reward:10	random_act:6	predict_act:10
# Ep:360	reward:16	random_act:8	predict_act:14
# Ep:361	reward:3	random_act:2	predict_act:7
# Ep:362	reward:5	random_act:1	predict_act:10
# Ep:363	reward:29	random_act:9	predict_act:26
# Ep:364	reward:4	random_act:2	predict_act:8
# Ep:365	reward:51	random_act:18	predict_act:39
# Ep:366	reward:21	random_act:8	predict_act:19
# Ep:367	reward:13	random_act:4	predict_act:15
# Ep:368	reward:38	random_act:16	predict_act:28
# Ep:369	reward:64	random_act:13	predict_act:57
# Ep:370	reward:23	random_act:4	predict_act:25
# Ep:371	reward:119	random_act:29	predict_act:96
# Ep:372	reward:36	random_act:8	predict_act:34
# Ep:373	reward:5	random_act:1	predict_act:10
# Ep:374	reward:5	random_act:4	predict_act:7
# Ep:375	reward:8	random_act:4	predict_act:10
# Ep:376	reward:9	random_act:2	predict_act:13
# Ep:377	reward:4	random_act:1	predict_act:9
# Ep:378	reward:70	random_act:24	predict_act:52
# Ep:379	reward:5	random_act:1	predict_act:10
# Ep:380	reward:4	random_act:0	predict_act:10
# Ep:381	reward:123	random_act:25	predict_act:104
# Ep:382	reward:35	random_act:7	predict_act:34
# Ep:383	reward:4	random_act:2	predict_act:8
# Ep:384	reward:2	random_act:1	predict_act:7
# Ep:385	reward:12	random_act:2	predict_act:16
# Ep:386	reward:9	random_act:4	predict_act:11
# Ep:387	reward:9	random_act:3	predict_act:12
# Ep:388	reward:8	random_act:0	predict_act:14
# Ep:389	reward:5	random_act:1	predict_act:10
# Ep:390	reward:51	random_act:7	predict_act:50
# Ep:391	reward:70	random_act:11	predict_act:65
# Ep:392	reward:8	random_act:3	predict_act:11
# Ep:393	reward:6	random_act:2	predict_act:10
# Ep:394	reward:16	random_act:5	predict_act:17
# Ep:395	reward:9	random_act:2	predict_act:13
# Ep:396	reward:6	random_act:2	predict_act:10
# Ep:397	reward:14	random_act:1	predict_act:19
# Ep:398	reward:7	random_act:1	predict_act:12
# Ep:399	reward:6	random_act:3	predict_act:9
# Ep:400	reward:10	random_act:6	predict_act:10
# Ep:401	reward:57	random_act:12	predict_act:51
# Ep:402	reward:3	random_act:2	predict_act:7
# Ep:403	reward:7	random_act:2	predict_act:11
# Ep:404	reward:5	random_act:2	predict_act:9
# Ep:405	reward:5	random_act:3	predict_act:8
# Ep:406	reward:4	random_act:0	predict_act:10
# Ep:407	reward:7	random_act:1	predict_act:12
# Ep:408	reward:13	random_act:1	predict_act:18
# Ep:409	reward:4	random_act:2	predict_act:8
# Ep:410	reward:93	random_act:18	predict_act:81
# Ep:411	reward:121	random_act:12	predict_act:115
# Ep:412	reward:76	random_act:7	predict_act:75
# Ep:413	reward:83	random_act:10	predict_act:79
# Ep:414	reward:106	random_act:7	predict_act:105
# Ep:415	reward:4	random_act:0	predict_act:10
# Ep:416	reward:4	random_act:1	predict_act:9
# Ep:417	reward:44	random_act:6	predict_act:44
# Ep:418	reward:55	random_act:7	predict_act:54
# Ep:419	reward:100	random_act:16	predict_act:90
# Ep:420	reward:155	random_act:17	predict_act:144
# Ep:421	reward:103	random_act:10	predict_act:99
# Ep:422	reward:104	random_act:10	predict_act:100
# Ep:423	reward:87	random_act:11	predict_act:82
# Ep:424	reward:90	random_act:12	predict_act:84
# Ep:425	reward:135	random_act:20	predict_act:121
# Ep:426	reward:103	random_act:11	predict_act:98
# Ep:427	reward:165	random_act:17	predict_act:154
# Ep:428	reward:141	random_act:15	predict_act:132
# Ep:429	reward:117	random_act:7	predict_act:116
# Ep:430	reward:133	random_act:13	predict_act:126
# Ep:431	reward:159	random_act:17	predict_act:148
# Ep:432	reward:170	random_act:14	predict_act:162
# Ep:433	reward:63	random_act:10	predict_act:59
# Ep:434	reward:115	random_act:11	predict_act:110
# Ep:435	reward:97	random_act:8	predict_act:95
# Ep:436	reward:178	random_act:20	predict_act:164
# Ep:437	reward:185	random_act:16	predict_act:175
# Ep:438	reward:119	random_act:11	predict_act:114
# Ep:439	reward:122	random_act:7	predict_act:121
# Ep:440	reward:117	random_act:10	predict_act:113
# Ep:441	reward:222	random_act:17	predict_act:211
# Ep:442	reward:132	random_act:14	predict_act:124
# Ep:443	reward:182	random_act:18	predict_act:170
# Ep:444	reward:163	random_act:17	predict_act:152
# Ep:445	reward:184	random_act:25	predict_act:165
# Ep:446	reward:129	random_act:16	predict_act:119
# Ep:447	reward:279	random_act:29	predict_act:256
# Ep:448	reward:358	random_act:47	predict_act:317
# Ep:449	reward:217	random_act:19	predict_act:204
# Ep:450	reward:156	random_act:20	predict_act:142
# Ep:451	reward:209	random_act:29	predict_act:186
# Ep:452	reward:356	random_act:40	predict_act:322
# Ep:453	reward:210	random_act:25	predict_act:191
# Ep:454	reward:187	random_act:22	predict_act:171
# Ep:455	reward:256	random_act:25	predict_act:237
# Ep:456	reward:255	random_act:29	predict_act:232
# Ep:457	reward:232	random_act:20	predict_act:218
# Ep:458	reward:139	random_act:11	predict_act:134
# Ep:459	reward:192	random_act:19	predict_act:179
# Ep:460	reward:515	random_act:52	predict_act:469
# Ep:461	reward:250	random_act:19	predict_act:237
# Ep:462	reward:488	random_act:49	predict_act:445
# Ep:463	reward:324	random_act:34	predict_act:296
# Ep:464	reward:246	random_act:22	predict_act:230
# Ep:465	reward:259	random_act:30	predict_act:235
# Ep:466	reward:255	random_act:28	predict_act:233
# Ep:467	reward:368	random_act:30	predict_act:344
# Ep:468	reward:258	random_act:24	predict_act:240
# Ep:469	reward:291	random_act:32	predict_act:265
# Ep:470	reward:284	random_act:29	predict_act:261
# Ep:471	reward:275	random_act:25	predict_act:256
# Ep:472	reward:254	random_act:30	predict_act:230
# Ep:473	reward:210	random_act:19	predict_act:197
# Ep:474	reward:388	random_act:30	predict_act:364
# Ep:475	reward:322	random_act:43	predict_act:285
# Ep:476	reward:323	random_act:25	predict_act:304
# Ep:477	reward:339	random_act:42	predict_act:303
# Ep:478	reward:252	random_act:25	predict_act:233
# Ep:479	reward:385	random_act:42	predict_act:349
# Ep:480	reward:359	random_act:37	predict_act:328
# Ep:481	reward:324	random_act:23	predict_act:307
# Ep:482	reward:265	random_act:24	predict_act:247
# Ep:483	reward:360	random_act:38	predict_act:328
# Ep:484	reward:266	random_act:29	predict_act:243
# Ep:485	reward:325	random_act:35	predict_act:296
# Ep:486	reward:228	random_act:25	predict_act:209
# Ep:487	reward:276	random_act:25	predict_act:257
# Ep:488	reward:407	random_act:41	predict_act:372
# Ep:489	reward:317	random_act:29	predict_act:294
# Ep:490	reward:301	random_act:28	predict_act:279
# Ep:491	reward:229	random_act:26	predict_act:209
# Ep:492	reward:209	random_act:17	predict_act:198
# Ep:493	reward:206	random_act:22	predict_act:190
# Ep:494	reward:232	random_act:17	predict_act:221
# Ep:495	reward:281	random_act:25	predict_act:262
# Ep:496	reward:431	random_act:49	predict_act:388
# Ep:497	reward:487	random_act:53	predict_act:440
# Ep:498	reward:253	random_act:24	predict_act:235
# Ep:499	reward:529	random_act:57	predict_act:478
# Ep:500	reward:665	random_act:58	predict_act:613
# Ep:501	reward:387	random_act:45	predict_act:348
# Ep:502	reward:211	random_act:24	predict_act:193
# Ep:503	reward:385	random_act:40	predict_act:351
# Ep:504	reward:278	random_act:27	predict_act:257
# Ep:505	reward:225	random_act:24	predict_act:207
# Ep:506	reward:385	random_act:24	predict_act:367
# Ep:507	reward:425	random_act:44	predict_act:387
# Ep:508	reward:206	random_act:23	predict_act:189
# Ep:509	reward:255	random_act:29	predict_act:232
# Ep:510	reward:184	random_act:22	predict_act:168
# Ep:511	reward:268	random_act:22	predict_act:252
# Ep:512	reward:305	random_act:27	predict_act:284
# Ep:513	reward:234	random_act:39	predict_act:201
# Ep:514	reward:223	random_act:23	predict_act:206
# Ep:515	reward:249	random_act:36	predict_act:219
# Ep:516	reward:296	random_act:39	predict_act:263
# Ep:517	reward:292	random_act:32	predict_act:266
# Ep:518	reward:329	random_act:28	predict_act:307
# Ep:519	reward:553	random_act:54	predict_act:505
# Ep:520	reward:348	random_act:34	predict_act:320
# Ep:521	reward:332	random_act:31	predict_act:307
# Ep:522	reward:371	random_act:24	predict_act:353
# Ep:523	reward:320	random_act:29	predict_act:297
# Ep:524	reward:421	random_act:46	predict_act:381
# Ep:525	reward:257	random_act:24	predict_act:239
# Ep:526	reward:359	random_act:50	predict_act:315
# Ep:527	reward:318	random_act:40	predict_act:284
# Ep:528	reward:279	random_act:23	predict_act:262
# Ep:529	reward:303	random_act:28	predict_act:281
# Ep:530	reward:303	random_act:29	predict_act:280
# Ep:531	reward:254	random_act:32	predict_act:228
# Ep:532	reward:310	random_act:32	predict_act:284
# Ep:533	reward:397	random_act:52	predict_act:351
# Ep:534	reward:507	random_act:63	predict_act:450
# Ep:535	reward:515	random_act:52	predict_act:469
# Ep:536	reward:379	random_act:45	predict_act:340
# Ep:537	reward:332	random_act:35	predict_act:303
# Ep:538	reward:349	random_act:34	predict_act:321
# Ep:539	reward:300	random_act:23	predict_act:283
# Ep:540	reward:382	random_act:41	predict_act:347
# Ep:541	reward:383	random_act:43	predict_act:346
# Ep:542	reward:464	random_act:47	predict_act:423
# Ep:543	reward:327	random_act:26	predict_act:307
# Ep:544	reward:330	random_act:36	predict_act:300
# Ep:545	reward:326	random_act:32	predict_act:300
# Ep:546	reward:513	random_act:52	predict_act:467
# Ep:547	reward:562	random_act:58	predict_act:510
# Ep:548	reward:340	random_act:28	predict_act:318
# Ep:549	reward:286	random_act:25	predict_act:267
# Ep:550	reward:347	random_act:41	predict_act:312
# Ep:551	reward:355	random_act:35	predict_act:326
# Ep:552	reward:367	random_act:30	predict_act:343
# Ep:553	reward:427	random_act:39	predict_act:394
# Ep:554	reward:397	random_act:39	predict_act:364
# Ep:555	reward:311	random_act:29	predict_act:288
# Ep:556	reward:437	random_act:55	predict_act:388
# Ep:557	reward:417	random_act:33	predict_act:390
# Ep:558	reward:423	random_act:39	predict_act:390
# Ep:559	reward:22	random_act:7	predict_act:21
# Ep:560	reward:449	random_act:61	predict_act:394
# Ep:561	reward:441	random_act:44	predict_act:403
# Ep:562	reward:381	random_act:54	predict_act:333
# Ep:563	reward:331	random_act:43	predict_act:294
# Ep:564	reward:428	random_act:51	predict_act:383
# Ep:565	reward:367	random_act:53	predict_act:320
# Ep:566	reward:449	random_act:50	predict_act:405
# Ep:567	reward:434	random_act:44	predict_act:396
# Ep:568	reward:373	random_act:39	predict_act:340
# Ep:569	reward:385	random_act:28	predict_act:363
# Ep:570	reward:387	random_act:34	predict_act:359
# Ep:571	reward:434	random_act:47	predict_act:393
# Ep:572	reward:476	random_act:51	predict_act:431
# Ep:573	reward:457	random_act:50	predict_act:413
# Ep:574	reward:152	random_act:23	predict_act:135
# Ep:575	reward:272	random_act:24	predict_act:254
# Ep:576	reward:455	random_act:50	predict_act:411
# Ep:577	reward:468	random_act:48	predict_act:426
# Ep:578	reward:458	random_act:51	predict_act:413
# Ep:579	reward:570	random_act:56	predict_act:520
# Ep:580	reward:504	random_act:57	predict_act:453
# Ep:581	reward:33	random_act:5	predict_act:34
# Ep:582	reward:130	random_act:19	predict_act:117
# Ep:583	reward:50	random_act:3	predict_act:53
# Ep:584	reward:47	random_act:3	predict_act:50
# Ep:585	reward:26	random_act:5	predict_act:27
# Ep:586	reward:62	random_act:11	predict_act:57
# Ep:587	reward:21	random_act:2	predict_act:25
# Ep:588	reward:21	random_act:1	predict_act:26
# Ep:589	reward:16	random_act:2	predict_act:20
# Ep:590	reward:34	random_act:5	predict_act:35
# Ep:591	reward:90	random_act:4	predict_act:92
# Ep:592	reward:18	random_act:3	predict_act:21
# Ep:593	reward:16	random_act:3	predict_act:19
# Ep:594	reward:42	random_act:8	predict_act:40
# Ep:595	reward:16	random_act:0	predict_act:22
# Ep:596	reward:15	random_act:2	predict_act:19
# Ep:597	reward:18	random_act:0	predict_act:24
# Ep:598	reward:45	random_act:7	predict_act:44
# Ep:599	reward:95	random_act:8	predict_act:93
# Ep:600	reward:24	random_act:2	predict_act:28
# Ep:601	reward:20	random_act:0	predict_act:26
# Ep:602	reward:534	random_act:56	predict_act:484
# Ep:603	reward:426	random_act:27	predict_act:405
# Ep:604	reward:394	random_act:41	predict_act:359
# Ep:605	reward:211	random_act:14	predict_act:203
# Ep:606	reward:684	random_act:84	predict_act:606
# Ep:607	reward:531	random_act:59	predict_act:478
# Ep:608	reward:445	random_act:51	predict_act:400
# Ep:609	reward:494	random_act:37	predict_act:463
# Ep:610	reward:538	random_act:74	predict_act:470
# Ep:611	reward:459	random_act:37	predict_act:428
# Ep:612	reward:424	random_act:44	predict_act:386
# Ep:613	reward:429	random_act:54	predict_act:381
# Ep:614	reward:563	random_act:49	predict_act:520
# Ep:615	reward:455	random_act:52	predict_act:409
# Ep:616	reward:497	random_act:45	predict_act:458
# Ep:617	reward:608	random_act:59	predict_act:555
# Ep:618	reward:30	random_act:6	predict_act:30
# Ep:619	reward:468	random_act:46	predict_act:428
# Ep:620	reward:537	random_act:63	predict_act:480
# Ep:621	reward:568	random_act:53	predict_act:521
# Ep:622	reward:475	random_act:44	predict_act:437
# Ep:623	reward:576	random_act:58	predict_act:524
# Ep:624	reward:618	random_act:70	predict_act:554
# Ep:625	reward:545	random_act:54	predict_act:497
# Ep:626	reward:572	random_act:66	predict_act:512
# Ep:627	reward:763	random_act:65	predict_act:704
# Ep:628	reward:550	random_act:47	predict_act:509
# Ep:629	reward:550	random_act:62	predict_act:494
# Ep:630	reward:491	random_act:48	predict_act:449
# Ep:631	reward:455	random_act:39	predict_act:422
# Ep:632	reward:493	random_act:48	predict_act:451
# Ep:633	reward:466	random_act:48	predict_act:424
# Ep:634	reward:373	random_act:51	predict_act:328
# Ep:635	reward:490	random_act:43	predict_act:453
# Ep:636	reward:457	random_act:56	predict_act:407
# Ep:637	reward:545	random_act:43	predict_act:508
# Ep:638	reward:417	random_act:36	predict_act:387
# Ep:639	reward:416	random_act:45	predict_act:377
# Ep:640	reward:397	random_act:50	predict_act:353
# Ep:641	reward:320	random_act:30	predict_act:296
# Ep:642	reward:449	random_act:46	predict_act:409
# Ep:643	reward:387	random_act:42	predict_act:351
# Ep:644	reward:360	random_act:28	predict_act:338
# Ep:645	reward:449	random_act:48	predict_act:407
# Ep:646	reward:418	random_act:41	predict_act:383
# Ep:647	reward:438	random_act:60	predict_act:384
# Ep:648	reward:435	random_act:53	predict_act:388
# Ep:649	reward:414	random_act:35	predict_act:385
# Ep:650	reward:345	random_act:38	predict_act:313
# Ep:651	reward:392	random_act:41	predict_act:357
# Ep:652	reward:424	random_act:41	predict_act:389
# Ep:653	reward:435	random_act:52	predict_act:389
# Ep:654	reward:617	random_act:66	predict_act:557
# Ep:655	reward:576	random_act:60	predict_act:522
# Ep:656	reward:1002	random_act:111	predict_act:891
# Ep:657	reward:394	random_act:47	predict_act:353
# Ep:658	reward:1002	random_act:115	predict_act:887
# Ep:659	reward:1002	random_act:111	predict_act:891
# Ep:660	reward:1002	random_act:99	predict_act:903
# Ep:661	reward:879	random_act:83	predict_act:802
# Ep:662	reward:188	random_act:20	predict_act:174
# Ep:663	reward:244	random_act:21	predict_act:229
# Ep:664	reward:661	random_act:70	predict_act:597
# Ep:665	reward:1002	random_act:98	predict_act:904
# Ep:666	reward:202	random_act:23	predict_act:185
# Ep:667	reward:504	random_act:66	predict_act:444
# Ep:668	reward:387	random_act:47	predict_act:346
# Ep:669	reward:101	random_act:14	predict_act:93
# Ep:670	reward:101	random_act:12	predict_act:95
# Ep:671	reward:122	random_act:11	predict_act:117
# Ep:672	reward:118	random_act:13	predict_act:111
# Ep:673	reward:96	random_act:11	predict_act:91
# Ep:674	reward:125	random_act:11	predict_act:120
# Ep:675	reward:190	random_act:18	predict_act:178
# Ep:676	reward:117	random_act:12	predict_act:111
# Ep:677	reward:101	random_act:14	predict_act:93
# Ep:678	reward:66	random_act:7	predict_act:65
# Ep:679	reward:94	random_act:13	predict_act:87
# Ep:680	reward:39	random_act:3	predict_act:42
# Ep:681	reward:199	random_act:15	predict_act:190
# Ep:682	reward:176	random_act:18	predict_act:164
# Ep:683	reward:226	random_act:19	predict_act:213
# Ep:684	reward:88	random_act:6	predict_act:88
# Ep:685	reward:96	random_act:7	predict_act:95
# Ep:686	reward:116	random_act:9	predict_act:113
# Ep:687	reward:186	random_act:29	predict_act:163
# Ep:688	reward:121	random_act:15	predict_act:112
# Ep:689	reward:111	random_act:8	predict_act:109
# Ep:690	reward:145	random_act:13	predict_act:138
# Ep:691	reward:49	random_act:7	predict_act:48
# Ep:692	reward:150	random_act:21	predict_act:135
# Ep:693	reward:158	random_act:15	predict_act:149
# Ep:694	reward:103	random_act:13	predict_act:96
# Ep:695	reward:122	random_act:16	predict_act:112
# Ep:696	reward:145	random_act:19	predict_act:132
# Ep:697	reward:92	random_act:10	predict_act:88
# Ep:698	reward:57	random_act:6	predict_act:57
# Ep:699	reward:103	random_act:13	predict_act:96
# Ep:700	reward:84	random_act:16	predict_act:74
# Ep:701	reward:135	random_act:9	predict_act:132
# Ep:702	reward:135	random_act:10	predict_act:131
# Ep:703	reward:142	random_act:16	predict_act:132
# Ep:704	reward:98	random_act:6	predict_act:98
# Ep:705	reward:96	random_act:10	predict_act:92
# Ep:706	reward:41	random_act:3	predict_act:44
# Ep:707	reward:29	random_act:5	predict_act:30
# Ep:708	reward:103	random_act:12	predict_act:97
# Ep:709	reward:130	random_act:15	predict_act:121
# Ep:710	reward:20	random_act:3	predict_act:23
# Ep:711	reward:17	random_act:3	predict_act:20
# Ep:712	reward:28	random_act:5	predict_act:29
# Ep:713	reward:25	random_act:4	predict_act:27
# Ep:714	reward:13	random_act:3	predict_act:16
# Ep:715	reward:26	random_act:2	predict_act:30
# Ep:716	reward:20	random_act:1	predict_act:25
# Ep:717	reward:40	random_act:1	predict_act:45
# Ep:718	reward:117	random_act:8	predict_act:115
# Ep:719	reward:110	random_act:14	predict_act:102
# Ep:720	reward:65	random_act:5	predict_act:66
# Ep:721	reward:136	random_act:16	predict_act:126
# Ep:722	reward:101	random_act:12	predict_act:95
# Ep:723	reward:125	random_act:3	predict_act:128
# Ep:724	reward:164	random_act:18	predict_act:152
# Ep:725	reward:132	random_act:12	predict_act:126
# Ep:726	reward:56	random_act:8	predict_act:54
# Ep:727	reward:126	random_act:10	predict_act:122
# Ep:728	reward:108	random_act:7	predict_act:107
# Ep:729	reward:179	random_act:19	predict_act:166
# Ep:730	reward:136	random_act:12	predict_act:130
# Ep:731	reward:204	random_act:22	predict_act:188
# Ep:732	reward:60	random_act:8	predict_act:58
# Ep:733	reward:178	random_act:23	predict_act:161
# Ep:734	reward:153	random_act:12	predict_act:147
# Ep:735	reward:125	random_act:11	predict_act:120
# Ep:736	reward:125	random_act:12	predict_act:119
# Ep:737	reward:129	random_act:16	predict_act:119
# Ep:738	reward:94	random_act:11	predict_act:89
# Ep:739	reward:143	random_act:18	predict_act:131
# Ep:740	reward:148	random_act:13	predict_act:141
# Ep:741	reward:137	random_act:12	predict_act:131
# Ep:742	reward:124	random_act:11	predict_act:119
# Ep:743	reward:95	random_act:9	predict_act:92
# Ep:744	reward:28	random_act:2	predict_act:32
# Ep:745	reward:140	random_act:11	predict_act:135
# Ep:746	reward:130	random_act:13	predict_act:123
# Ep:747	reward:127	random_act:13	predict_act:120
# Ep:748	reward:81	random_act:12	predict_act:75
# Ep:749	reward:97	random_act:19	predict_act:84
# Ep:750	reward:86	random_act:10	predict_act:82
# Ep:751	reward:29	random_act:2	predict_act:33
# Ep:752	reward:33	random_act:5	predict_act:34
# Ep:753	reward:28	random_act:6	predict_act:28
# Ep:754	reward:22	random_act:3	predict_act:25
# Ep:755	reward:110	random_act:16	predict_act:100
# Ep:756	reward:103	random_act:8	predict_act:101
# Ep:757	reward:84	random_act:15	predict_act:75
# Ep:758	reward:86	random_act:12	predict_act:80
# Ep:759	reward:21	random_act:1	predict_act:26
# Ep:760	reward:57	random_act:6	predict_act:57
# Ep:761	reward:91	random_act:14	predict_act:83
# Ep:762	reward:40	random_act:4	predict_act:42
# Ep:763	reward:97	random_act:14	predict_act:89
# Ep:764	reward:120	random_act:9	predict_act:117
# Ep:765	reward:105	random_act:7	predict_act:104
# Ep:766	reward:106	random_act:14	predict_act:98
# Ep:767	reward:107	random_act:9	predict_act:104
# Ep:768	reward:111	random_act:8	predict_act:109
# Ep:769	reward:97	random_act:13	predict_act:90
# Ep:770	reward:88	random_act:8	predict_act:86
# Ep:771	reward:106	random_act:6	predict_act:106
# Ep:772	reward:128	random_act:18	predict_act:116
# Ep:773	reward:97	random_act:7	predict_act:96
# Ep:774	reward:101	random_act:17	predict_act:90
# Ep:775	reward:124	random_act:12	predict_act:118
# Ep:776	reward:98	random_act:14	predict_act:90
# Ep:777	reward:81	random_act:8	predict_act:79
# Ep:778	reward:93	random_act:9	predict_act:90
# Ep:779	reward:94	random_act:13	predict_act:87
# Ep:780	reward:88	random_act:15	predict_act:79
# Ep:781	reward:95	random_act:8	predict_act:93
# Ep:782	reward:100	random_act:6	predict_act:100
# Ep:783	reward:109	random_act:13	predict_act:102
# Ep:784	reward:105	random_act:12	predict_act:99
# Ep:785	reward:87	random_act:8	predict_act:85
# Ep:786	reward:108	random_act:6	predict_act:108
# Ep:787	reward:100	random_act:8	predict_act:98
# Ep:788	reward:113	random_act:16	predict_act:103
# Ep:789	reward:92	random_act:3	predict_act:95
# Ep:790	reward:128	random_act:13	predict_act:121
# Ep:791	reward:108	random_act:10	predict_act:104
# Ep:792	reward:124	random_act:11	predict_act:119
# Ep:793	reward:108	random_act:15	predict_act:99
# Ep:794	reward:109	random_act:12	predict_act:103
# Ep:795	reward:98	random_act:7	predict_act:97
# Ep:796	reward:101	random_act:14	predict_act:93
# Ep:797	reward:113	random_act:14	predict_act:105
# Ep:798	reward:118	random_act:10	predict_act:114
# Ep:799	reward:114	random_act:14	predict_act:106
# Ep:800	reward:144	random_act:18	predict_act:132
# Ep:801	reward:147	random_act:18	predict_act:135
# Ep:802	reward:145	random_act:14	predict_act:137
# Ep:803	reward:127	random_act:17	predict_act:116
# Ep:804	reward:125	random_act:14	predict_act:117
# Ep:805	reward:150	random_act:18	predict_act:138
# Ep:806	reward:170	random_act:12	predict_act:164
# Ep:807	reward:151	random_act:18	predict_act:139
# Ep:808	reward:162	random_act:11	predict_act:157
# Ep:809	reward:160	random_act:17	predict_act:149
# Ep:810	reward:186	random_act:19	predict_act:173
# Ep:811	reward:164	random_act:18	predict_act:152
# Ep:812	reward:194	random_act:27	predict_act:173
# Ep:813	reward:187	random_act:15	predict_act:178
# Ep:814	reward:235	random_act:24	predict_act:217
# Ep:815	reward:303	random_act:34	predict_act:275
# Ep:816	reward:183	random_act:18	predict_act:171
# Ep:817	reward:195	random_act:21	predict_act:180
# Ep:818	reward:189	random_act:24	predict_act:171
# Ep:819	reward:213	random_act:18	predict_act:201
# Ep:820	reward:249	random_act:21	predict_act:234
# Ep:821	reward:306	random_act:25	predict_act:287
# Ep:822	reward:197	random_act:18	predict_act:185
# Ep:823	reward:191	random_act:19	predict_act:178
# Ep:824	reward:162	random_act:19	predict_act:149
# Ep:825	reward:178	random_act:17	predict_act:167
# Ep:826	reward:179	random_act:17	predict_act:168
# Ep:827	reward:271	random_act:35	predict_act:242
# Ep:828	reward:216	random_act:27	predict_act:195
# Ep:829	reward:192	random_act:16	predict_act:182
# Ep:830	reward:180	random_act:15	predict_act:171
# Ep:831	reward:176	random_act:25	predict_act:157
# Ep:832	reward:190	random_act:19	predict_act:177
# Ep:833	reward:198	random_act:19	predict_act:185
# Ep:834	reward:185	random_act:27	predict_act:164
# Ep:835	reward:185	random_act:15	predict_act:176
# Ep:836	reward:202	random_act:29	predict_act:179
# Ep:837	reward:210	random_act:20	predict_act:196
# Ep:838	reward:197	random_act:24	predict_act:179
# Ep:839	reward:191	random_act:24	predict_act:173
# Ep:840	reward:196	random_act:23	predict_act:179
# Ep:841	reward:217	random_act:24	predict_act:199
# Ep:842	reward:222	random_act:27	predict_act:201
# Ep:843	reward:230	random_act:18	predict_act:218
# Ep:844	reward:214	random_act:33	predict_act:187
# Ep:845	reward:199	random_act:29	predict_act:176
# Ep:846	reward:203	random_act:16	predict_act:193
# Ep:847	reward:208	random_act:16	predict_act:198
# Ep:848	reward:190	random_act:17	predict_act:179
# Ep:849	reward:207	random_act:21	predict_act:192
# Ep:850	reward:205	random_act:25	predict_act:186
# Ep:851	reward:201	random_act:21	predict_act:186
# Ep:852	reward:208	random_act:22	predict_act:192
# Ep:853	reward:204	random_act:28	predict_act:182
# Ep:854	reward:195	random_act:21	predict_act:180
# Ep:855	reward:210	random_act:30	predict_act:186
# Ep:856	reward:219	random_act:21	predict_act:204
# Ep:857	reward:221	random_act:18	predict_act:209
# Ep:858	reward:199	random_act:36	predict_act:169
# Ep:859	reward:203	random_act:24	predict_act:185
# Ep:860	reward:207	random_act:21	predict_act:192
# Ep:861	reward:194	random_act:17	predict_act:183
# Ep:862	reward:235	random_act:25	predict_act:216
# Ep:863	reward:225	random_act:21	predict_act:210
# Ep:864	reward:211	random_act:23	predict_act:194
# Ep:865	reward:210	random_act:24	predict_act:192
# Ep:866	reward:204	random_act:18	predict_act:192
# Ep:867	reward:238	random_act:30	predict_act:214
# Ep:868	reward:218	random_act:20	predict_act:204
# Ep:869	reward:213	random_act:15	predict_act:204
# Ep:870	reward:226	random_act:16	predict_act:216
# Ep:871	reward:208	random_act:19	predict_act:195
# Ep:872	reward:219	random_act:17	predict_act:208
# Ep:873	reward:204	random_act:20	predict_act:190
# Ep:874	reward:237	random_act:20	predict_act:223
# Ep:875	reward:213	random_act:23	predict_act:196
# Ep:876	reward:236	random_act:15	predict_act:227
# Ep:877	reward:234	random_act:20	predict_act:220
# Ep:878	reward:223	random_act:29	predict_act:200
# Ep:879	reward:255	random_act:24	predict_act:237
# Ep:880	reward:218	random_act:21	predict_act:203
# Ep:881	reward:228	random_act:29	predict_act:205
# Ep:882	reward:229	random_act:19	predict_act:216
# Ep:883	reward:261	random_act:31	predict_act:236
# Ep:884	reward:214	random_act:28	predict_act:192
# Ep:885	reward:223	random_act:24	predict_act:205
# Ep:886	reward:250	random_act:22	predict_act:234
# Ep:887	reward:243	random_act:27	predict_act:222
# Ep:888	reward:219	random_act:26	predict_act:199
# Ep:889	reward:241	random_act:24	predict_act:223
# Ep:890	reward:247	random_act:27	predict_act:226
# Ep:891	reward:230	random_act:16	predict_act:220
# Ep:892	reward:242	random_act:31	predict_act:217
# Ep:893	reward:216	random_act:24	predict_act:198
# Ep:894	reward:232	random_act:12	predict_act:226
# Ep:895	reward:218	random_act:23	predict_act:201
# Ep:896	reward:245	random_act:32	predict_act:219
# Ep:897	reward:228	random_act:21	predict_act:213
# Ep:898	reward:217	random_act:26	predict_act:197
# Ep:899	reward:207	random_act:31	predict_act:182
# Ep:900	reward:233	random_act:24	predict_act:215
# Ep:901	reward:198	random_act:28	predict_act:176
# Ep:902	reward:201	random_act:21	predict_act:186
# Ep:903	reward:213	random_act:20	predict_act:199
# Ep:904	reward:241	random_act:24	predict_act:223
# Ep:905	reward:225	random_act:22	predict_act:209
# Ep:906	reward:235	random_act:23	predict_act:218
# Ep:907	reward:200	random_act:19	predict_act:187
# Ep:908	reward:237	random_act:15	predict_act:228
# Ep:909	reward:242	random_act:28	predict_act:220
# Ep:910	reward:224	random_act:24	predict_act:206
# Ep:911	reward:195	random_act:23	predict_act:178
# Ep:912	reward:221	random_act:20	predict_act:207
# Ep:913	reward:226	random_act:27	predict_act:205
# Ep:914	reward:196	random_act:24	predict_act:178
# Ep:915	reward:208	random_act:28	predict_act:186
# Ep:916	reward:208	random_act:17	predict_act:197
# Ep:917	reward:244	random_act:17	predict_act:233
# Ep:918	reward:239	random_act:21	predict_act:224
# Ep:919	reward:217	random_act:23	predict_act:200
# Ep:920	reward:208	random_act:17	predict_act:197
# Ep:921	reward:231	random_act:17	predict_act:220
# Ep:922	reward:212	random_act:21	predict_act:197
# Ep:923	reward:218	random_act:30	predict_act:194
# Ep:924	reward:226	random_act:23	predict_act:209
# Ep:925	reward:277	random_act:26	predict_act:257
# Ep:926	reward:284	random_act:36	predict_act:254
# Ep:927	reward:247	random_act:24	predict_act:229
# Ep:928	reward:261	random_act:32	predict_act:235
# Ep:929	reward:232	random_act:26	predict_act:212
# Ep:930	reward:271	random_act:20	predict_act:257
# Ep:931	reward:268	random_act:21	predict_act:253
# Ep:932	reward:251	random_act:19	predict_act:238
# Ep:933	reward:227	random_act:29	predict_act:204
# Ep:934	reward:228	random_act:21	predict_act:213
# Ep:935	reward:270	random_act:28	predict_act:248
# Ep:936	reward:235	random_act:25	predict_act:216
# Ep:937	reward:231	random_act:31	predict_act:206
# Ep:938	reward:251	random_act:19	predict_act:238
# Ep:939	reward:228	random_act:20	predict_act:214
# Ep:940	reward:232	random_act:33	predict_act:205
# Ep:941	reward:257	random_act:14	predict_act:249
# Ep:942	reward:243	random_act:20	predict_act:229
# Ep:943	reward:246	random_act:27	predict_act:225
# Ep:944	reward:226	random_act:21	predict_act:211
# Ep:945	reward:233	random_act:15	predict_act:224
# Ep:946	reward:261	random_act:27	predict_act:240
# Ep:947	reward:283	random_act:23	predict_act:266
# Ep:948	reward:241	random_act:21	predict_act:226
# Ep:949	reward:244	random_act:22	predict_act:228
# Ep:950	reward:215	random_act:15	predict_act:206
# Ep:951	reward:107	random_act:8	predict_act:105
# Ep:952	reward:214	random_act:28	predict_act:192
# Ep:953	reward:230	random_act:33	predict_act:203
# Ep:954	reward:248	random_act:16	predict_act:238
# Ep:955	reward:233	random_act:32	predict_act:207
# Ep:956	reward:239	random_act:29	predict_act:216
# Ep:957	reward:234	random_act:28	predict_act:212
# Ep:958	reward:262	random_act:29	predict_act:239
# Ep:959	reward:211	random_act:21	predict_act:196
# Ep:960	reward:217	random_act:22	predict_act:201
# Ep:961	reward:225	random_act:21	predict_act:210
# Ep:962	reward:261	random_act:20	predict_act:247
# Ep:963	reward:185	random_act:22	predict_act:169
# Ep:964	reward:285	random_act:25	predict_act:266
# Ep:965	reward:252	random_act:28	predict_act:230
# Ep:966	reward:244	random_act:22	predict_act:228
# Ep:967	reward:273	random_act:35	predict_act:244
# Ep:968	reward:272	random_act:24	predict_act:254
# Ep:969	reward:237	random_act:33	predict_act:210
# Ep:970	reward:310	random_act:33	predict_act:283
# Ep:971	reward:254	random_act:24	predict_act:236
# Ep:972	reward:266	random_act:27	predict_act:245
# Ep:973	reward:212	random_act:23	predict_act:195
# Ep:974	reward:247	random_act:24	predict_act:229
# Ep:975	reward:280	random_act:21	predict_act:265
# Ep:976	reward:260	random_act:30	predict_act:236
# Ep:977	reward:296	random_act:24	predict_act:278
# Ep:978	reward:208	random_act:22	predict_act:192
# Ep:979	reward:268	random_act:31	predict_act:243
# Ep:980	reward:257	random_act:27	predict_act:236
# Ep:981	reward:274	random_act:29	predict_act:251
# Ep:982	reward:402	random_act:45	predict_act:363
# Ep:983	reward:320	random_act:26	predict_act:300
# Ep:984	reward:299	random_act:34	predict_act:271
# Ep:985	reward:306	random_act:44	predict_act:268
# Ep:986	reward:341	random_act:37	predict_act:310
# Ep:987	reward:260	random_act:20	predict_act:246
# Ep:988	reward:307	random_act:30	predict_act:283
# Ep:989	reward:598	random_act:53	predict_act:551
# Ep:990	reward:323	random_act:31	predict_act:298
# Ep:991	reward:369	random_act:34	predict_act:341
# Ep:992	reward:354	random_act:40	predict_act:320
# Ep:993	reward:307	random_act:26	predict_act:287
# Ep:994	reward:275	random_act:21	predict_act:260
# Ep:995	reward:366	random_act:30	predict_act:342
# Ep:996	reward:327	random_act:31	predict_act:302
# Ep:997	reward:272	random_act:30	predict_act:248
# Ep:998	reward:319	random_act:40	predict_act:285
# Ep:999	reward:290	random_act:26	predict_act:270
# Ep:1000	reward:250	random_act:31	predict_act:225
# Ep:1001	reward:327	random_act:20	predict_act:313
# Ep:1002	reward:304	random_act:33	predict_act:277
# Ep:1003	reward:300	random_act:22	predict_act:284
# Ep:1004	reward:354	random_act:36	predict_act:324
# Ep:1005	reward:393	random_act:32	predict_act:367
# Ep:1006	reward:339	random_act:35	predict_act:310
# Ep:1007	reward:337	random_act:31	predict_act:312
# Ep:1008	reward:304	random_act:43	predict_act:267
# Ep:1009	reward:529	random_act:56	predict_act:479
# Ep:1010	reward:1002	random_act:99	predict_act:903
# Ep:1011	reward:448	random_act:37	predict_act:417
# Ep:1012	reward:479	random_act:50	predict_act:435
# Ep:1013	reward:469	random_act:35	predict_act:440
# Ep:1014	reward:578	random_act:58	predict_act:526
# Ep:1015	reward:563	random_act:56	predict_act:513
# Ep:1016	reward:397	random_act:41	predict_act:362
# Ep:1017	reward:330	random_act:36	predict_act:300
# Ep:1018	reward:418	random_act:36	predict_act:388
# Ep:1019	reward:1002	random_act:98	predict_act:904
# Ep:1020	reward:1002	random_act:100	predict_act:902
# Ep:1021	reward:705	random_act:78	predict_act:633
# Ep:1022	reward:1002	random_act:113	predict_act:889
# Ep:1023	reward:1002	random_act:81	predict_act:921
# Ep:1024	reward:1002	random_act:106	predict_act:896
# Ep:1025	reward:1002	random_act:94	predict_act:908
# Ep:1026	reward:1002	random_act:91	predict_act:911
# Ep:1027	reward:1002	random_act:118	predict_act:884
# Ep:1028	reward:1002	random_act:104	predict_act:898
# Ep:1029	reward:1002	random_act:104	predict_act:898
# Ep:1030	reward:1002	random_act:84	predict_act:918
# Ep:1031	reward:1002	random_act:111	predict_act:891
# Ep:1032	reward:1002	random_act:90	predict_act:912
# Ep:1033	reward:1002	random_act:113	predict_act:889
# Ep:1034	reward:1002	random_act:115	predict_act:887
# Ep:1035	reward:1002	random_act:102	predict_act:900
# Ep:1036	reward:1002	random_act:99	predict_act:903
# Ep:1037	reward:1002	random_act:85	predict_act:917
# Ep:1038	reward:1002	random_act:104	predict_act:898
# Ep:1039	reward:1002	random_act:111	predict_act:891
# Ep:1040	reward:1002	random_act:105	predict_act:897
# Ep:1041	reward:1002	random_act:101	predict_act:901
# Ep:1042	reward:1002	random_act:93	predict_act:909
# Ep:1043	reward:1002	random_act:96	predict_act:906
# Ep:1044	reward:1002	random_act:98	predict_act:904
# Ep:1045	reward:1002	random_act:90	predict_act:912
# Ep:1046	reward:1002	random_act:86	predict_act:916
# Stopped - 500 avg scores reached!

# %%
# print statistics  
print "max score:{} at episode:{}".format(max_reward,max_ep)
plt.plot(episode_rewards, lw=1)
plt.show()
plt.plot(loss, lw=1, c='r')
plt.show()
# Out:
# max score:1002.0 at episode:656

# %%
# for testing
episode_rewards_test = np.zeros(100)

for i_episode in xrange(100):

    state = env.reset()
    # init state
    state = np.array(state)
    for _ in xrange(AGENT_HISTORY_LENGTH):
        state_history.append(state)
    state = np.array(state_history)
    state = state.flatten()


    for t in itertools.count():
        # action

        q_values = train_model.predict(np.array([state]))[0]
        action = np.argmax(q_values)

        next_state, reward, done, info = env.step(action)
        
        # set the negative reward when the game end  
        if done == True :
            reward = -5

        # clip reward [-5,1]
        reward = max(-5, min(1, reward))
        
        # append next state
        next_state = np.array(next_state)
        state_history.append(next_state)
        next_state = np.array(state_history)
        next_state = next_state.flatten()
        
        # Save transition to replay memory
        replay_memory.append(Transition(state, action, reward, next_state, done))   
        
        # Update statistics
        episode_rewards_test[i_episode] += reward   

        # check if terminated
        if done or t > LIMIT_MAX_SCORE :
            break
        else:
            state = next_state
            
   
    
    ####### EPISODE END

    
    # print statistics    
    print 'Ep:%i\treward:%i' % (i_episode,episode_rewards_test[i_episode])
    
# print statistics   
print np.mean(episode_rewards_test)
# Out:
# Ep:0	reward:1002
# Ep:1	reward:1002
# Ep:2	reward:1002
# Ep:3	reward:1002
# Ep:4	reward:1002
# Ep:5	reward:1002
# Ep:6	reward:1002
# Ep:7	reward:1002
# Ep:8	reward:1002
# Ep:9	reward:1002
# Ep:10	reward:1002
# Ep:11	reward:1002
# Ep:12	reward:1002
# Ep:13	reward:1002
# Ep:14	reward:1002
# Ep:15	reward:1002
# Ep:16	reward:1002
# Ep:17	reward:1002
# Ep:18	reward:1002
# Ep:19	reward:1002
# Ep:20	reward:1002
# Ep:21	reward:1002
# Ep:22	reward:1002
# Ep:23	reward:1002
# Ep:24	reward:1002
# Ep:25	reward:1002
# Ep:26	reward:1002
# Ep:27	reward:1002
# Ep:28	reward:1002
# Ep:29	reward:1002
# Ep:30	reward:1002
# Ep:31	reward:1002
# Ep:32	reward:1002
# Ep:33	reward:1002
# Ep:34	reward:1002
# Ep:35	reward:1002
# Ep:36	reward:1002
# Ep:37	reward:1002
# Ep:38	reward:1002
# Ep:39	reward:1002
# Ep:40	reward:1002
# Ep:41	reward:1002
# Ep:42	reward:1002
# Ep:43	reward:1002
# Ep:44	reward:1002
# Ep:45	reward:1002
# Ep:46	reward:1002
# Ep:47	reward:1002
# Ep:48	reward:1002
# Ep:49	reward:1002
# Ep:50	reward:1002
# Ep:51	reward:1002
# Ep:52	reward:1002
# Ep:53	reward:1002
# Ep:54	reward:1002
# Ep:55	reward:1002
# Ep:56	reward:1002
# Ep:57	reward:1002
# Ep:58	reward:1002
# Ep:59	reward:1002
# Ep:60	reward:1002
# Ep:61	reward:1002
# Ep:62	reward:1002
# Ep:63	reward:1002
# Ep:64	reward:1002
# Ep:65	reward:1002
# Ep:66	reward:1002
# Ep:67	reward:1002
# Ep:68	reward:1002
# Ep:69	reward:1002
# Ep:70	reward:1002
# Ep:71	reward:1002
# Ep:72	reward:1002
# Ep:73	reward:1002
# Ep:74	reward:1002
# Ep:75	reward:1002
# Ep:76	reward:1002
# Ep:77	reward:1002
# Ep:78	reward:1002
# Ep:79	reward:1002
# Ep:80	reward:1002
# Ep:81	reward:1002
# Ep:82	reward:1002
# Ep:83	reward:1002
# Ep:84	reward:1002
# Ep:85	reward:1002
# Ep:86	reward:1002
# Ep:87	reward:1002
# Ep:88	reward:1002
# Ep:89	reward:1002
# Ep:90	reward:1002
# Ep:91	reward:1002
# Ep:92	reward:1002
# Ep:93	reward:1002
# Ep:94	reward:1002
# Ep:95	reward:1002
# Ep:96	reward:1002
# Ep:97	reward:1002
# Ep:98	reward:1002
# Ep:99	reward:1002
# 1002.0
